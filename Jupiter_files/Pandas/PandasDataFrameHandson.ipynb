# %%
import numpy as np
import pandas as pd

# %%
df= pd.DataFrame({'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]})
df
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(exam_data,index=labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.describe()
# Out:
#            score   attempts
# count   8.000000  10.000000
# mean   13.562500   1.900000
# std     4.693746   0.875595
# min     8.000000   1.000000
# 25%     9.000000   1.000000
# 50%    13.500000   2.000000
# 75%    17.125000   2.750000
# max    20.000000   3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   score     8 non-null      float64
#  2   attempts  10 non-null     int64
#  3   qualify   10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.head(3)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
df[['name','score']]
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
df[['name','score']].iloc[[1, 3, 5, 6]]
# Out:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %%
df[df['attempts'] > 2]
# Out:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %%
len(df.columns)
# Out:
# 4

# %%
len(df)
# Out:
# 10

# %%
df[df['score'].isna()]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %%
df[df['score'].between(15,20,inclusive='both')]
# Out:
#         name  score  attempts qualify
# c  Katherine   16.5         2     yes
# f    Michael   20.0         3     yes
# j      Jonas   19.0         1     yes

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df[(df['attempts']<2) & (df['score']>15)]
# Out:
#     name  score  attempts qualify
# j  Jonas   19.0         1     yes

# %%
df.loc['d'].score = 11.5
# Out:
# C:\Users\SPURUSHO\AppData\Local\Temp\ipykernel_4052\2120593333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc['d'].score = 11.5

# %%
df.loc['d','score'] = 11.5

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df['attempts'].sum()
# Out:
# 19

# %%
df['score'].mean()
# Out:
# 13.333333333333334

# %%
s = pd.Series( {"name" : "Suresh", "score": 15.5, "attempts": 1, "qualify": "yes", "label": "k"})
s
# Out:
# name        Suresh
# score         15.5
# attempts         1
# qualify        yes
# label            k
# dtype: object

# %%
df1 = pd.DataFrame(s)
df1
# Out:
#                0
# name      Suresh
# score       15.5
# attempts       1
# qualify      yes
# label          k

# %%
df.loc['l'] =  {"score": 15.5, "attempts": 1, "qualify": "yes"}

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     Suresh   15.5         1     yes
# l        NaN   15.5         1     yes

# %%
df.drop(labels='k')
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# l        NaN   15.5         1     yes

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     Suresh   15.5         1     yes
# l        NaN   15.5         1     yes

# %%
df.drop(labels=['k','l'],inplace=True)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.qualify
# Out:
# a    yes
# b     no
# c    yes
# d     no
# e     no
# f    yes
# g    yes
# h     no
# i     no
# j    yes
# Name: qualify, dtype: object

# %%
df['qualify'].replace(to_replace='True',value=True,inplace=True)
df['qualify'].replace(to_replace='False',value=False,inplace=True)

# %%
df
# Out:
#         name  score  attempts  qualify
# a  Anastasia   12.5         1     True
# b       Dima    9.0         3    False
# c  Katherine   16.5         2     True
# d      James   11.5         3    False
# e      Emily    9.0         2    False
# f    Michael   20.0         3     True
# g    Matthew   14.5         1     True
# h      Laura    NaN         1    False
# i      Kevin    8.0         2    False
# j      Jonas   19.0         1     True

# %%
df['name'].replace(to_replace='James',value='Suresh',inplace = True)
df
# Out:
#         name  score  attempts  qualify
# a  Anastasia   12.5         1     True
# b       Dima    9.0         3    False
# c  Katherine   16.5         2     True
# d     Suresh   11.5         3    False
# e      Emily    9.0         2    False
# f    Michael   20.0         3     True
# g    Matthew   14.5         1     True
# h      Laura    NaN         1    False
# i      Kevin    8.0         2    False
# j      Jonas   19.0         1     True

# %%
df.drop('attempts',axis=1,inplace=True)

# %%
df
# Out:
#         name  score  qualify
# a  Anastasia   12.5     True
# b       Dima    9.0    False
# c  Katherine   16.5     True
# d     Suresh   11.5    False
# e      Emily    9.0    False
# f    Michael   20.0     True
# g    Matthew   14.5     True
# h      Laura    NaN    False
# i      Kevin    8.0    False
# j      Jonas   19.0     True

# %%
df['colors'] = ['red','yellow','green','blue','white','brown','black','pink','orange','voilet']

# %%
df
# Out:
#         name  score  qualify  colors
# a  Anastasia   12.5     True     red
# b       Dima    9.0    False  yellow
# c  Katherine   16.5     True   green
# d     Suresh   11.5    False    blue
# e      Emily    9.0    False   white
# f    Michael   20.0     True   brown
# g    Matthew   14.5     True   black
# h      Laura    NaN    False    pink
# i      Kevin    8.0    False  orange
# j      Jonas   19.0     True  voilet

# %%
for index, row in df.iterrows():
    print(row['name'], row['score'])
# Out:
# Anastasia 12.5
# Dima 9.0
# Katherine 16.5
# Suresh 11.5
# Emily 9.0
# Michael 20.0
# Matthew 14.5
# Laura nan
# Kevin 8.0
# Jonas 19.0

# %%
list(df.columns)
# Out:
# ['name', 'score', 'qualify', 'colors']

# %%
li = np.random.randint(1,10,(3,3))

# %%
li
# Out:
# array([[6, 4, 8],
#        [4, 2, 4],
#        [3, 5, 9]])

# %%
df = pd.DataFrame(li,columns=['col1','col2','col3'])
df
# Out:
#    col1  col2  col3
# 0     6     4     8
# 1     4     2     4
# 2     3     5     9
